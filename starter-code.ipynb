# %%
import json

# %%
with open('full_data.json', 'r') as file:
    data = json.load(file)

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 1200

# %%
type(data[0])
# Out:
# dict

# %%
data[0].keys()
# Out:
# dict_keys(['_id', 'type', 'question', 'context', 'supporting_facts', 'evidences', 'answer', 'retrieved'])

# %%
for key in data[0].keys():
    print(f"{key}       {type(key)}")
# Out:
# _id       <class 'str'>
# type       <class 'str'>
# question       <class 'str'>
# context       <class 'str'>
# supporting_facts       <class 'str'>
# evidences       <class 'str'>
# answer       <class 'str'>
# retrieved       <class 'str'>

# %%
from src.load_data import load_json
random_docs_pool = load_json("data/random_docs.json")

# %%
print(type(data[0]["retrieved"]))
print(data[0]["retrieved"][:2])

print(type(random_docs_pool[0]))
print(random_docs_pool[0])
# Out:
# <class 'list'>
# ['Polish-Russian War (Wojna polsko-ruska) is a 2009 Polish film directed by Xawery Żuławski based on the novel Polish-Russian War under the white-red flag by Dorota Masłowska.', 'Polish- Russian War( Wojna polsko- ruska) is a 2009 Polish film directed by Xawery Żuławski based on the novel Polish- Russian War under the white- red flag by Dorota Masłowska.']
# <class 'str'>
# Jesse Davis (born September 11, 1965) is an American jazz saxophonist.
